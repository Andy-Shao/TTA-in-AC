# %% [markdown]
# # Speech Commands

# %%
import pandas as pd
import numpy as np
import os
from lib.ablationStudyUtils import loss_ablation, format_loss

root_path = './result/speech-commands/CoNMix/ablation_study'
accu_10dB = pd.read_csv(os.path.join(root_path, 'accu-10dB-SC.csv'), sep=',')
accu_10dB.head()
# Out:
#    Step  DD-10dB-no_nm  DD-10dB-no_cst  DD-10dB-no_pl  DD-10dB-org  \
# 0   0.0      87.315289       88.792977      88.778347    88.529627
# 1   1.0      59.780541       90.226774      90.182882    89.729334
# 2   2.0      26.188734       90.299927      90.241405    89.480614
# 3   3.0      14.235552       90.270666      90.270666    89.378200
# 4   4.0       5.193855       90.226774      90.387710    89.378200
#
#    EB-10dB-no_nm  EB-10dB-no_cst  EB-10dB-no_pl  EB-10dB-org  RT-10dB-no_nm  \
# 0      86.891002       89.188003      89.363570    88.807608      87.417703
# 1      46.730066       90.826628      90.899781    90.446233      40.775421
# 2       4.754938       90.738844      90.855889    90.197513       6.335040
# 3       4.038040       90.826628      90.738844    90.153621       4.711046
# 4       4.052670       90.768105      90.958303    89.890271       4.038040
#
#    RT-10dB-no_cst  RT-10dB-org  RT-10dB-no_pl  RT-10dB-upd  EB-10dB-upd  \
# 0       89.831748    89.656181      89.802487    90.314557    89.568398
# 1       91.060717    90.475494      91.060717    91.865399    91.163131
# 2       90.855889    90.256035      91.075347    91.938552    91.133870
# 3       90.563277    90.007315      90.855889    91.850768    91.426481
# 4       91.002195    90.226774      91.192392    91.938552    91.572787
#
#    DD-10dB-upd
# 0    89.583029
# 1    90.782736
# 2    90.899781
# 3    91.119239
# 4    91.148500

# %%
x = np.arange(21)
loss_ablation(
    x=x, 
    title='CoNMix Prediction Accuracy (%) under 10dB Running Tap Background Noise \n in Speech Commands',
    lines=format_loss(
        origin=accu_10dB['RT-10dB-org'], updated=accu_10dB['RT-10dB-upd'], no_pl=accu_10dB['RT-10dB-no_pl'],
        no_cst=accu_10dB['RT-10dB-no_cst']
    )
)

# %%
loss_ablation(
    x=x,
    title='CoNMix Prediction Accuracy (%) under 10dB Exercise Bike Backgournd Noise \n in Speech Commands',
    lines=format_loss(
        origin=accu_10dB['EB-10dB-org'], updated=accu_10dB['EB-10dB-upd'], no_pl=accu_10dB['EB-10dB-no_pl'],
        no_cst=accu_10dB['EB-10dB-no_cst']
    )
)

# %%
loss_ablation(
    x=x,
    lines=format_loss(
        origin=accu_10dB['DD-10dB-org'], updated=accu_10dB['DD-10dB-upd'], no_pl=accu_10dB['DD-10dB-no_pl'],
        no_cst=accu_10dB['DD-10dB-no_cst']
    ),
    title='CoNMix Prediction Accuracy (%) under 10dB Doing the Dishes Backgournd \n Noise in Speech Commands'
)

# %%
lines = {
    'running tap': {
        'data': accu_10dB['RT-10dB-no_nm'].loc[:20],
        'linestyle': '-',
        'color': 'b'
    },
    'exercise bike': {
        'data': accu_10dB['EB-10dB-no_nm'].loc[:20],
        'linestyle': '-',
        'color': 'g'
    },
    'doing the dishes': {
        'data': accu_10dB['DD-10dB-no_nm'].loc[:20],
        'linestyle': '-',
        'color': 'r'
    }
}
loss_ablation(
    x=x,
    title='CoNMix Prediction Accuracy (%), which excludes the Nuclear-norm Loss, \n under 10dB Background Noise in Speech Commands',
    lines=lines
)

# %%
PL_10dB = pd.read_csv(os.path.join(root_path, 'pl-10dB-SC.csv'))
PL_10dB.head()
# Out:
#    Step  DD-10dB-no_nm  DD-10dB-no_cst  DD-10dB-no_pl  DD-10dB-org  \
# 0   0.0       3.057467        3.086896            0.0     3.084612
# 1   1.0       3.025807        3.346129            0.0     3.328807
# 2   2.0       2.571975        3.428516            0.0     3.398150
# 3   3.0       2.414406        3.480708            0.0     3.437285
# 4   4.0       2.347503        3.515691            0.0     3.463352
#
#    EB-10dB-no_nm  EB-10dB-no_cst  EB-10dB-no_pl  EB-10dB-org  RT-10dB-no_nm  \
# 0       3.029127        3.069124            0.0     3.065924       3.029798
# 1       2.954947        3.348405            0.0     3.329054       2.926465
# 2       2.447412        3.431275            0.0     3.400588       2.391862
# 3       2.332993        3.476884            0.0     3.434609       2.338326
# 4       2.354359        3.514090            0.0     3.463938       2.351864
#
#    RT-10dB-no_cst  RT-10dB-org  RT-10dB-no_pl  RT-10dB-upd  EB-10dB-upd  \
# 0        3.071954     3.068525            0.0     0.236008     0.235644
# 1        3.356643     3.337826            0.0     0.193320     0.194038
# 2        3.440915     3.411075            0.0     0.153053     0.155995
# 3        3.488383     3.445594            0.0     0.137436     0.141490
# 4        3.519962     3.473359            0.0     0.131219     0.129226
#
#    DD-10dB-upd
# 0     0.234617
# 1     0.194857
# 2     0.162375
# 3     0.144065
# 4     0.134825

# %%
lines = {
    'DD-no_cst': {
        'data': PL_10dB['DD-10dB-no_cst'].loc[:20],
        'linestyle': '-',
        'color': 'b'
    },
    'DD-org': {
        'data': PL_10dB['DD-10dB-org'].loc[:20],
        'linestyle': '-.',
        'color': 'b'
    },
    'EB-no_cst': {
        'data': PL_10dB['EB-10dB-no_cst'].loc[:20],
        'linestyle': '-',
        'color': 'g'
    },
    'EB-org': {
        'data': PL_10dB['EB-10dB-org'].loc[:20],
        'linestyle': '-.',
        'color': 'g'
    },
    'RT-no_cst': {
        'data': PL_10dB['RT-10dB-no_cst'].loc[:20],
        'linestyle': '-',
        'color': 'r'
    },
    'RT-org': {
        'data': PL_10dB['RT-10dB-org'].loc[:20],
        'linestyle': '-.',
        'color': 'r'
    }
}
loss_ablation(
    x=x,
    title='Original CoNMix Pseduo-label Loss \n under 10dB Background Noises in Speech Commands',
    lines=lines,
    ylabel='Pseudo-label Loss'
)

# %%
lines = {
    'doing the dishes': {
        'data': PL_10dB['DD-10dB-upd'].loc[:20],
        'linestyle': '-',
        'color': 'b'
    },
    'exercise bike': {
        'data': PL_10dB['EB-10dB-upd'].loc[:20],
        'linestyle': '-',
        'color': 'g'
    },
    'running tap': {
        'data': PL_10dB['RT-10dB-upd'].loc[:20],
        'linestyle': '-',
        'color': 'r'
    }
}
loss_ablation(
    x=x,
    title='Updated CoNMix Pseduo-label Loss \n under 10dB Background Noises in Speech Commands',
    lines=lines,
    ylabel='Pseudo-label Loss'
)

# %%
accu_3dB = pd.read_csv(os.path.join(root_path, 'accu-3dB-SC.csv'), sep=',')
accu_3dB.head()
# Out:
#    Step  DD-3dB-no_cst  DD-3dB-org  RT-3dB-upd  EB-3dB-upd  DD-3dB-upd  \
# 0     0      79.005121   78.536942   85.032919   82.282370   79.853694
# 1     1      83.189466   82.179956   87.095830   84.623263   83.452816
# 2     2      83.862473   82.633504   87.681053   85.076811   83.818581
# 3     3      84.140454   83.321141   87.549378   85.281639   84.272129
# 4     4      84.403804   83.028530   87.593270   85.457206   84.637893
#
#    RT-3dB-no_nm  RT-3dB-no_cst  RT-3dB-no_pl  RT-3dB-org  EB-3dB-no_nm  \
# 0     80.219459      84.301390     84.067301   83.760059     76.839795
# 1     31.192392      87.154353     86.715435   86.057059     30.753475
# 2      5.135333      87.212875     86.934894   85.676664      9.027067
# 3      3.847842      86.920263     87.139722   85.588881      4.418435
# 4      3.847842      87.403072     87.432334   85.910753      3.950256
#
#    EB-3dB-no_cst  EB-3dB-no_pl  EB-3dB-org  DD-3dB-no_pl  DD-3dB-no_nm
# 0      81.916606     81.872714   81.506950     78.961229     74.440380
# 1      84.637893     84.535479   84.096562     83.277249     39.722019
# 2      84.974396     84.696416   83.716167     83.847842     15.566935
# 3      85.149963     85.047549   83.950256     84.272129      6.817849
# 4      85.179225     85.193855   83.906364     84.520849      4.447696

# %%
loss_ablation(
    x=x,
    title='CoNMix Prediction Accuracy (%) under 3dB Running Tap Background Noise \n in Speech Commands',
    lines=format_loss(
        origin=accu_3dB['RT-3dB-org'], updated=accu_3dB['RT-3dB-upd'], no_pl=accu_3dB['RT-3dB-no_pl'],
        no_cst=accu_3dB['RT-3dB-no_cst']
    )
)

# %%
loss_ablation(
    x=x,
    title='CoNMix Prediction Accuracy (%) under 3dB Exercise Bike Backgournd Noise \n in Speech Commands',
    lines=format_loss(
        origin=accu_3dB['EB-3dB-org'], updated=accu_3dB['EB-3dB-upd'], no_pl=accu_3dB['EB-3dB-no_pl'],
        no_cst=accu_3dB['EB-3dB-no_cst']
    )
)

# %%
loss_ablation(
    x=x,
    title='CoNMix Prediction Accuracy (%) under 3dB Doing the Dishes Backgournd \n Noise in Speech Commands',
    lines=format_loss(
        origin=accu_3dB['DD-3dB-org'], updated=accu_3dB['DD-3dB-upd'], no_pl=accu_3dB['DD-3dB-no_pl'],
        no_cst=accu_3dB['DD-3dB-no_cst']
    )
)

# %%
loss_ablation(
    x=x,
    title='CoNMix Prediction Accuracy (%), which excludes the Nuclear-norm Loss, \n under 3dB Background Noise in Speech Commands',
    lines= {
        'running tap': {
            'data': accu_3dB['RT-3dB-no_nm'].loc[:20],
            'linestyle': '-',
            'color': 'b'
        },
        'exercise bike': {
            'data': accu_3dB['EB-3dB-no_nm'].loc[:20],
            'linestyle': '-',
            'color': 'g'
        },
        'doing the dishes': {
            'data': accu_3dB['DD-3dB-no_nm'].loc[:20],
            'linestyle': '-',
            'color': 'r'
        }
    }
)

# %%
PL_3dB = pd.read_csv(os.path.join(root_path, 'pl-3dB-SC.csv'), sep=',')
PL_3dB.head()
# Out:
#    Step  DD-3dB-no_cst  DD-3dB-org  running_tap_3.0  exercise_bike_3.0  \
# 0     0       2.939165    2.936692         0.320401           0.360217
# 1     1       3.192373    3.175112         0.255610           0.278618
# 2     2       3.313628    3.284423         0.200026           0.217807
# 3     3       3.382852    3.342253         0.172535           0.190519
# 4     4       3.433520    3.386016         0.161511           0.175027
#
#    doing_the_dishes_3.0  RT-3dB-no_nm  RT-3dB-no_cst  RT-3dB-no_pl  \
# 0              0.378365      2.914597       2.968702           0.0
# 1              0.309916      2.807585       3.260922           0.0
# 2              0.239472      2.418416       3.360454           0.0
# 3              0.206596      2.348352       3.417844           0.0
# 4              0.185682      2.358539       3.460704           0.0
#
#    RT-3dB-org  EB-3dB-no_nm  EB-3dB-no_cst  EB-3dB-no_pl  EB-3dB-org  \
# 0    2.964923      2.891793       2.943675           0.0    2.940274
# 1    3.242913      2.799303       3.224472           0.0    3.208578
# 2    3.333685      2.448431       3.336311           0.0    3.307736
# 3    3.379931      2.360376       3.397115           0.0    3.356895
# 4    3.417053      2.356303       3.450670           0.0    3.402250
#
#    DD-3dB-no_pl  DD-3dB-no_nm
# 0           0.0      2.901328
# 1           0.0      2.848209
# 2           0.0      2.516056
# 3           0.0      2.393684
# 4           0.0      2.360715

# %%
loss_ablation(
    x=x,
    title='Original CoNMix Pseduo-label Loss \n under 3dB Background Noises in Speech Commands',
    lines={
        'DD-no_cst': {
            'data': PL_3dB['DD-3dB-no_cst'].loc[:20],
            'linestyle': '-',
            'color': 'b'
        },
        'DD-org': {
            'data': PL_3dB['DD-3dB-org'].loc[:20],
            'linestyle': '-.',
            'color': 'b'
        },
        'EB-no_cst': {
            'data': PL_3dB['EB-3dB-no_cst'].loc[:20],
            'linestyle': '-',
            'color': 'g'
        },
        'EB-org': {
            'data': PL_3dB['EB-3dB-org'].loc[:20],
            'linestyle': '-.',
            'color': 'g'
        },
        'RT-no_cost': {
            'data': PL_3dB['RT-3dB-no_cst'].loc[:20],
            'linestyle': '-',
            'color': 'r'
        },
        'RT-org': {
            'data': PL_3dB['RT-3dB-org'].loc[:20],
            'linestyle': '-.',
            'color': 'r'
        }
    }
)

# %%
loss_ablation(
    x=x,
    title='Updated CoNMix Pseduo-label Loss \n under 3dB Background Noises in Speech Commands',
    lines={
        'doing the dishes': {
            'data': PL_3dB['doing_the_dishes_3.0'].loc[:20],
            'linestyle': '-',
            'color': 'b'
        },
        'exercise bike': {
            'data': PL_3dB['exercise_bike_3.0'].loc[:20],
            'linestyle': '-',
            'color': 'g'
        },
        'running tap': {
            'data': PL_3dB['running_tap_3.0'].loc[:20],
            'linestyle': '-',
            'color': 'r'
        }
    }
)
